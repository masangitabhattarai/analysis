# %% [markdown]
# importing necessary library

# %%
import pandas as pd 
import numpy as numpy
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# load datasets

# %%
df = pd.read_csv("../dataset/hotel_booking.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.shape
# Out:
# (119390, 36)

# %% [markdown]
# Basics information of data

# %%
# structure and size
before = df.shape[0]
print(before)
# Out:
# 119390

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Variable type
numerical = df.select_dtypes(include=['int64','float64']).columns
print("numerical",list(numerical))
# Out:
# numerical ['is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']

# %%
# Variable type
Categorical = df.select_dtypes(include=['object']).columns
print("categorical",list(Categorical))
# Out:
# categorical ['hotel', 'arrival_date_month', 'meal', 'country', 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status', 'reservation_status_date', 'name', 'email', 'phone-number', 'credit_card']

# %%
# Variable type
date_related = ['reservation_status_date','arrival_date_year','arrival_date_month','arrival_date_day_of month']
print("date_related",list(date_related))
# Out:
# date_related ['reservation_status_date', 'arrival_date_year', 'arrival_date_month', 'arrival_date_day_of month']

# %% [markdown]
# checking missing value exist in this dataset or not

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# above show the missing value, it must be handle

# %%
df= df.dropna()

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
df.shape
# Out:
# (217, 36)

# %%
after= df.shape[0]
print(after)
# Out:
# 217

# %%
print("deleated row", before - after)
# Out:
# deleated row 119173

# %% [markdown]
# Visualization of dataset

# %% [markdown]
# 1. visualization of Cancellation rates

# %%
sns.countplot(data=df, x='hotel', hue='is_canceled')
plt.title("Cancellation Rate by Hotel Type")
plt.show()

# %%
sns.countplot(data=df, x='customer_type', hue='is_canceled')
plt.title("Cancellation by Customer Type")
plt.show()

# %%
sns.countplot(data=df, x='arrival_date_month', hue='is_canceled', order=['January','February','March','April','May','June','July','August','September','October','November','December'])
plt.title("Cancellation by Season")
plt.xticks(rotation=45)
plt.show()

# %%
# Create subplots (1 row, 3 columns)
fig, axs = plt.subplots(1, 3, figsize=(40, 20))

# Plot 1: Cancellation Rate by Hotel Type
sns.countplot(data=df, x='hotel', hue='is_canceled', ax=axs[0])
axs[0].set_title("Cancellation Rate by Hotel Type")

# Plot 2: Cancellation by Customer Type
sns.countplot(data=df, x='customer_type', hue='is_canceled', ax=axs[1])
axs[1].set_title("Cancellation by Customer Type")

# Plot 3: Cancellation by Season (Month)
sns.countplot(data=df, x='arrival_date_month', hue='is_canceled',
              order=['January','February','March','April','May','June',
                     'July','August','September','October','November','December'],
              ax=axs[2])
axs[2].set_title("Cancellation by Season")
axs[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# visualization of Booking trends over time

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])
df.set_index('reservation_status_date', inplace=True)
df['is_canceled'].resample('ME').count().plot()
plt.title("Monthly Booking Trends")
plt.show()

# %% [markdown]
# Average Daily Rate  visulation

# %%
sns.boxplot(data=df, x='hotel', y= 'adr')
plt.title("ADR distribution by Hotel")
plt.show()

# %% [markdown]
# visulization of Correlation heatmap

# %%
# Only numeric columns
numeric_df = df.select_dtypes(include='number')

# Now plot correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Geographic analysis of the data

# %%
top_countries = df['country'].value_counts().head(10)
sns.barplot(x=top_countries.values, y=top_countries.index)
plt.title("Top 10 Booking Countries")
plt.xlabel("Number of Bookings")
plt.show()

# %% [markdown]
# Lead time vs Cancellation

# %%
sns.scatterplot(data=df, x='lead_time', y='is_canceled', alpha=0.3)
plt.title("Lead Time vs Cancellation")
plt.show()

# %% [markdown]
# Revenue Analysis

# %%
# Revenue impact
# Total revenue lost due to cancellations
canceled_revenue = df[df['is_canceled'] == 1]['adr'].sum()
completed_revenue = df[df['is_canceled'] == 0]['adr'].sum()
print("Revenue Lost:", canceled_revenue)
print("Revenue Earned:", completed_revenue)
# Out:
# Revenue Lost: 955.6
# Revenue Earned: 12887.64

# %%
# Market segment profitability
segment_revenue = df[df['is_canceled']==0].groupby('market_segment')['adr'].mean().sort_values(ascending=False)
segment_revenue.plot(kind='bar')
plt.title("Average Revenue by Market Segment")
plt.ylabel("ADR")
plt.show()

# %%
# pricing strategy and demand
sns.lineplot(data=df, x='lead_time', y='adr')
plt.title("Pricing Strategy Impact on Demand")
plt.show()

# %% [markdown]
# Customer Behavior Analysis

# %%
# Cancellation by customer segment
sns.barplot(data=df, x='customer_type', y='is_canceled')
plt.title("Cancellation Rate by Customer Type")
plt.show()

# %%
# Lead time effect
sns.histplot(data=df, x='lead_time', hue='is_canceled', multiple='stack')
plt.title("Lead Time vs Cancellation Probability")
plt.show()

# %%
# Special request impact
sns.barplot(data=df, x='total_of_special_requests', y='is_canceled')
plt.title("Special Requests vs Cancellation Rate")
plt.show()

# %% [markdown]
# Booking patterns

# %%
# Monthly booking demand
sns.countplot(data=df, x='arrival_date_month', order=['January','February','March','April','May','June','July','August','September','October','November','December'])
plt.title("Monthly Booking Demand")
plt.xticks(rotation=45)
plt.show()

# %%
# Booking patterns by hotel
sns.countplot(data=df, x='arrival_date_month', hue='hotel', order=['January','February','March','April','May','June','July','August','September','October','November','December'])
plt.title("Monthly Demand by Hotel Type")
plt.xticks(rotation=45)
plt.show()

# %%
# ADR Distribution
sns.histplot(data=df, x='adr', bins=50)
plt.title("ADR Distribution")
plt.show()

# %% [markdown]
# Market Analysis

# %%
# Country-wise bookings
country_count = df['country'].value_counts().head(10)
sns.barplot(y=country_count.index, x=country_count.values)
plt.title("Top Booking Countries")
plt.show()

# %%
# Market segment performance
market_counts = df['market_segment'].value_counts()
sns.barplot(x=market_counts.index, y=market_counts.values)
plt.title("Bookings by Market Segment")
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution channel impact
sns.boxplot(data=df, x='distribution_channel', y='adr')
plt.title("ADR by Distribution Channel")
plt.show()

# %% [markdown]
# Detecting and Removing Outliers

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return df[(df[column] >= lower) & (df[column] <= upper)]

df = remove_outliers(df, 'adr')
df = remove_outliers(df, 'lead_time')

# %%
# Check the shape before removing outliers
before_shape = df.shape

# Remove outliers
df = remove_outliers(df, 'adr')
df = remove_outliers(df, 'lead_time')

# Check the shape after removing outliers
after_shape = df.shape

print("Shape before removing outliers:", before_shape)
print("Shape after removing outliers:", after_shape)
print("Number of rows removed:", before_shape[0] - after_shape[0])
# Out:
# Shape before removing outliers: (192, 35)
# Shape after removing outliers: (160, 35)
# Number of rows removed: 32

# %%
# Boxplot before removing outliers
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(x=df['adr'])
plt.title("ADR Distribution Before Removing Outliers")
plt.subplot(1, 2, 2)
sns.boxplot(x=df['lead_time'])
plt.title("Lead Time Distribution Before Removing Outliers")
plt.show()

# %%
# Function to check for outliers
def check_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return df[(df[column] < lower) | (df[column] > upper)]
# Check for remaining outliers in 'adr' and 'lead_time'
remaining_outliers_adr = check_outliers(df, 'adr')
remaining_outliers_lead_time = check_outliers(df, 'lead_time')
print("Remaining outliers in ADR:", remaining_outliers_adr.shape[0])
print("Remaining outliers in Lead Time:", remaining_outliers_lead_time.shape[0])
# Out:
# Remaining outliers in ADR: 8
# Remaining outliers in Lead Time: 0

# %%
# Remove outliers again for ADR
df = remove_outliers(df, 'adr')
# Check for remaining outliers again
remaining_outliers_adr = check_outliers(df, 'adr')
print("Remaining outliers in ADR after second removal:", remaining_outliers_adr.shape[0])
# Out:
# Remaining outliers in ADR after second removal: 7
